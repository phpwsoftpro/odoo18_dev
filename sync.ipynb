# %%
import os
import subprocess
import time
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# Docker container name and paths
docker_container_name = "4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722"
container_path = "/mnt/extra-addons/custom_gmail"
local_path = "D:/odoo18_dev/custom/custom_gmail"

# Ensure the local folder exists
if not os.path.exists(local_path):
    os.makedirs(local_path)

# Function to check and create directory in Docker container if it doesn't exist
def create_directory_in_container(directory_in_container):
    # Check if directory exists in the container
    check_command = [
        "docker", "exec", docker_container_name, "bash", "-c", f"test -d {directory_in_container} || echo 'missing'"
    ]
    result = subprocess.run(check_command, capture_output=True, text=True)

    if 'missing' in result.stdout:
        print(f"Directory {directory_in_container} is missing in the container, creating it...")
        # Create the directory if it's missing
        create_command = [
            "docker", "exec", docker_container_name, "bash", "-c", f"mkdir -p {directory_in_container}"
        ]
        create_result = subprocess.run(create_command, capture_output=True, text=True)
        if create_result.returncode == 0:
            print(f"Successfully created directory: {directory_in_container}")
        else:
            print(f"Failed to create directory. Error: {create_result.stderr}")
    else:
        print(f"Directory {directory_in_container} exists in the container.")

# Function to sync a single file to the Docker container
def sync_file_to_container(src_path, relative_path):
    # Chuyển đổi đường dẫn Windows thành dạng Unix để tương thích với Docker
    dest_path = os.path.join(container_path, relative_path).replace("\\", "/")
    dest_dir = os.path.dirname(dest_path)  # Extract the directory part of the destination path

    # Ensure the target directory exists in the Docker container
    create_directory_in_container(dest_dir)

    print(f"Syncing {src_path} to {docker_container_name}:{dest_path}...")
    
    # Sử dụng docker cp để đồng bộ tệp đã thay đổi
    sync_command = [
        "docker", "cp", src_path, f"{docker_container_name}:{dest_path}"
    ]
    result = subprocess.run(sync_command, capture_output=True, text=True)
    
    if result.returncode == 0:
        print(f"Successfully synced {src_path} to Docker container.")
    else:
        print(f"Failed to sync {src_path}. Error: {result.stderr}")

# Function to download all files from Docker container to local folder (first run)
def download_from_container():
    print(f"Downloading all files from {docker_container_name}:{container_path} to {local_path}...")
    download_command = [
        "docker", "cp", f"{docker_container_name}:{container_path}.", local_path
    ]
    result = subprocess.run(download_command, capture_output=True, text=True)
    if result.returncode == 0:
        print(f"Successfully downloaded files to {local_path}.")
    else:
        print(f"Failed to download files from container. Error: {result.stderr}")

# File change handler for monitoring the local folder
class LocalFileChangeHandler(FileSystemEventHandler):
    def on_modified(self, event):
        # Ignore directory modifications and temporary files
        if event.is_directory or event.src_path.endswith('~'):
            return
        
        # Calculate the relative path of the changed file
        relative_path = os.path.relpath(event.src_path, local_path)
        sync_file_to_container(event.src_path, relative_path)

    def on_created(self, event):
        # Sync new files to the Docker container
        if not event.is_directory:
            relative_path = os.path.relpath(event.src_path, local_path)
            sync_file_to_container(event.src_path, relative_path)

# Function to start monitoring the local folder for changes
def start_monitoring():
    event_handler = LocalFileChangeHandler()
    observer = Observer()
    observer.schedule(event_handler, path=local_path, recursive=True)
    observer.start()
    print(f"Monitoring changes in {local_path}...")

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
    observer.join()

# Function to check if this is the first run (local folder is empty)
def is_first_run():
    return not os.listdir(local_path)

def main():
    if is_first_run():
        # First run: download everything from the Docker container to the local folder
        download_from_container()
    else:
        # Start monitoring the folder for changes and sync to Docker container
        start_monitoring()

# Corrected main check
if __name__ == "__main__":
    main()
# Out:
# Monitoring changes in D:/odoo18_dev/custom/custom_gmail...
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\gmail_config.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/gmail_config.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\gmail_config.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\main.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/main.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\main.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\outlook_auth.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/outlook_auth.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\outlook_auth.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\__init__.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/__init__.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\__init__.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\email_analyzer_service.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/email_analyzer_service.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\email_analyzer_service.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\__init__.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/__init__.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\__init__.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\outlook_controller.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/outlook_controller.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\outlook_controller.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\proxy_endpoint.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/proxy_endpoint.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\proxy_endpoint.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\__init__.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/__init__.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\__init__.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\gmail_account.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/gmail_account.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\gmail_account.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\gmail_inbox.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/gmail_inbox.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\gmail_inbox.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\gmail_sync.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/gmail_sync.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\gmail_sync.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\gmail_utils.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/gmail_utils.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\gmail_utils.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\mail_account.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/mail_account.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\mail_account.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\outlook_account.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/outlook_account.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\outlook_account.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\outlook_mail.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/outlook_mail.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\outlook_mail.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\outlook_message.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/outlook_message.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\outlook_message.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\proxy_endpoint.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/proxy_endpoint.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\proxy_endpoint.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\sort_kanban_views.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/sort_kanban_views.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\sort_kanban_views.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js/functions exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\onReply.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/functions/onReply.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\onReply.js to Docker container.
# Directory /mnt/extra-addons/custom_gmail exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\__manifest__.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/__manifest__.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\__manifest__.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\__manifest__.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/__manifest__.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\__manifest__.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\gmail_auth.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/gmail_auth.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\gmail_auth.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\gmail_auth.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/gmail_auth.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\gmail_auth.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\gmail_inbox_controller.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/gmail_inbox_controller.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\gmail_inbox_controller.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\gmail_inbox_controller.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/gmail_inbox_controller.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\gmail_inbox_controller.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\mail_auth_controller.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/mail_auth_controller.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\mail_auth_controller.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/controllers exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\controllers\mail_auth_controller.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/controllers/mail_auth_controller.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\controllers\mail_auth_controller.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\gmail_fetch.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/gmail_fetch.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\gmail_fetch.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/models exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\models\gmail_fetch.py to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/models/gmail_fetch.py...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\models\gmail_fetch.py to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\GmailInbox.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/GmailInbox.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\GmailInbox.js to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\GmailInbox.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/GmailInbox.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\GmailInbox.js to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js/functions exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\index.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/functions/index.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\index.js to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js/functions exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\index.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/functions/index.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\index.js to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js/functions exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\onDeleteMessage.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/functions/onDeleteMessage.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\onDeleteMessage.js to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js/functions exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\onDeleteMessage.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/functions/onDeleteMessage.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\onDeleteMessage.js to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\template.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/template.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\template.js to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\template.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/template.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\template.js to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js/functions exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\onForward.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/functions/onForward.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\onForward.js to Docker container.
# Directory /mnt/extra-addons/custom_gmail/static/src/js/functions exists in the container.
# Syncing D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\onSendEmail.js to 4c82ca0c5891488340f37ef158139e3ef9e32fdefba56a15b2d4c62a8a204722:/mnt/extra-addons/custom_gmail/static/src/js/functions/onSendEmail.js...
# Successfully synced D:/odoo18_dev/custom/custom_gmail\static\src\js\functions\onSendEmail.js to Docker container.
